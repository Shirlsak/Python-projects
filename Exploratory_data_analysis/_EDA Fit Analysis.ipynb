# %% [markdown]
# # Exploratory Data Analysis on FitBit Data

# %% [markdown]
# This is an Exploratory data analysis of the FitBit data to analyze, explore and summarize the characteristics of the data.
# The data used in this project contains information of one year of a human activity and gathered with a FitBit Charge HT fitness tracker and can be found on Kaggle:https://www.kaggle.com/datasets/singhakash/fitbit-dataset

# %% [markdown]
# IMPORTING PACKAGES
#
# The necessary packages needed for analysing the dataset were imported successfully.

# %%
#Import the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# LOADING THE DATA
#
# The data was loaded, and the csv file was read.

# %%
#Data Reading in pandas
fit= pd.read_csv('C:/Users/DELL/OneDrive/Desktop/Data Analyst Projects/Python/Project 2/FitBit data.csv')

# %%
fit
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
fit.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
fit.tail()
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
# ...

# %% [markdown]
# DATAFRAME & STATISTICAL DESCRIBE
#
# To understand the dataset and how it is distributed, the shape, size, head, and tail were generated. The statistical summary of the data was also generated showing count, mean, standard deviation, minimum, maximum and quartiles of each numerical columns. The data types were also generated which showed there were 14 numerical and 1 categorical features.

# %%
#Checking the statistical description of the data
fit.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  4.570000e+02    457.000000     457.000000       457.000000
# mean   4.628595e+09   6546.562363       4.663523         4.609847
# std    2.293781e+09   5398.493064       4.082072         4.068540
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.347168e+09   1988.000000       1.410000         1.280000
# 50%    4.057193e+09   5986.000000       4.090000         4.090000
# 75%    6.391747e+09  10198.000000       7.160000         7.110000
# max    8.877689e+09  28497.000000      27.530001        27.530001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                457.000000          457.000000                457.000000
# mean                   0.179427            1.180897                  0.478643
# std                    0.849232            2.487159                  0.830995
# ...

# %%
#understanding the dataset, the number of rows and columns
print('Shape of data set is:', fit.shape)
print('Size of data set is:', fit.size)
# Out:
# Shape of data set is: (457, 15)
# Size of data set is: 6855

# %%
#checking a quick description of the data types
fit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   ActivityDate              457 non-null    object
#  2   TotalSteps                457 non-null    int64
#  3   TotalDistance             457 non-null    float64
#  4   TrackerDistance           457 non-null    float64
#  5   LoggedActivitiesDistance  457 non-null    float64
#  6   VeryActiveDistance        457 non-null    float64
#  7   ModeratelyActiveDistance  457 non-null    float64
#  8   LightActiveDistance       457 non-null    float64
#  9   SedentaryActiveDistance   457 non-null    float64
#  10  VeryActiveMinutes         457 non-null    int64
#  11  FairlyActiveMinutes       457 non-null    int64
#  12  LightlyActiveMinutes      457 non-null    int64
# ...

# %% [markdown]
# Data Preprocessing
#
# There were no duplicates and missing values were found in the data. The unique values for each column were also checked. The column containing date values were transformed into 3 different columns day, month and year to identify patterns related to activity and calorie burn.

# %%
#Checking the data for duplicates
fit.duplicated().sum()
# Out:
# 0

# %%
#Checking the data for missing values
fit.isnull().sum()
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
#checking for number of columns with numerical data
num=fit.select_dtypes(include=np.number).columns

#checking the unique values in the numerical columns
for i in num:
    print('The number of unique values in', i, 'are:', fit.loc[:,i].nunique())
# Out:
# The number of unique values in Id are: 35
# The number of unique values in TotalSteps are: 389
# The number of unique values in TotalDistance are: 334
# The number of unique values in TrackerDistance are: 336
# The number of unique values in LoggedActivitiesDistance are: 20
# The number of unique values in VeryActiveDistance are: 170
# The number of unique values in ModeratelyActiveDistance are: 140
# The number of unique values in LightActiveDistance are: 295
# The number of unique values in SedentaryActiveDistance are: 8
# The number of unique values in VeryActiveMinutes are: 85
# The number of unique values in FairlyActiveMinutes are: 62
# The number of unique values in LightlyActiveMinutes are: 251
# The number of unique values in SedentaryMinutes are: 315
# The number of unique values in Calories are: 383

# %%
#checking for the number of columns with categorical data
cat=fit.select_dtypes(include='object').columns

#checking the unique values in the categorical columns
for i in cat:
    print('The number of unique values in', i, 'are:',fit.loc[:,i].nunique())
# Out:
# The number of unique values in ActivityDate are: 32

# %%
#checking unique activity dates in the data
fit['ActivityDate'].unique()
# Out:
# array(['3/25/2016', '3/26/2016', '3/27/2016', '3/28/2016', '3/29/2016',
#        '3/30/2016', '3/31/2016', '4/1/2016', '4/2/2016', '4/3/2016',
#        '4/4/2016', '4/5/2016', '4/6/2016', '4/7/2016', '4/8/2016',
#        '4/9/2016', '4/10/2016', '4/11/2016', '4/12/2016', '3/12/2016',
#        '3/13/2016', '3/14/2016', '3/15/2016', '3/16/2016', '3/17/2016',
#        '3/18/2016', '3/19/2016', '3/20/2016', '3/21/2016', '3/22/2016',
#        '3/23/2016', '3/24/2016'], dtype=object)

# %%
#splitting the Activity date to year, month and day columns and adding to the data
fit['year']= pd.DatetimeIndex(fit['ActivityDate']).year
fit['month']= pd.DatetimeIndex(fit['ActivityDate']).month
fit['day']= pd.DatetimeIndex(fit['ActivityDate']).day

# %%
#checking the data after transformation
fit.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
#checking data type after transformation
fit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   ActivityDate              457 non-null    object
#  2   TotalSteps                457 non-null    int64
#  3   TotalDistance             457 non-null    float64
#  4   TrackerDistance           457 non-null    float64
#  5   LoggedActivitiesDistance  457 non-null    float64
#  6   VeryActiveDistance        457 non-null    float64
#  7   ModeratelyActiveDistance  457 non-null    float64
#  8   LightActiveDistance       457 non-null    float64
#  9   SedentaryActiveDistance   457 non-null    float64
#  10  VeryActiveMinutes         457 non-null    int64
#  11  FairlyActiveMinutes       457 non-null    int64
#  12  LightlyActiveMinutes      457 non-null    int64
# ...

# %% [markdown]
# Univariate Analysis
#
# A visual analysis was generated to examine each column to understand the characteristics and patterns in them.

# %%
#visualizing all columns
#histogram for each numerical columns
fit.hist(bins=50, figsize=(20,15), color='green')
plt.show()

# %% [markdown]
# Bivariate Analysis
#
# To examine the relationship between the columns and the Calories, a bivariate analysis was done through boxplots,scatter plots, Line charts and a correlation heatmap. Also to capture trends and variations over time, aggregated features over specifi time periods were created and visualised.

# %%
plt.figure(figsize=(15,8))
ax = sns.boxplot(x='day', y='Calories', data=fit)
ax = sns.swarmplot(x='day', y='Calories', data=fit, color = 'black')
ax.set_title('Box plot of Calories by day')
# Out:
# Text(0.5, 1.0, 'Box plot of Calories by day')

# %%
plt.figure(figsize = (15,8))
ax= sns.scatterplot(x='Calories', y='TotalSteps', data= fit, color= 'green')
ax.set_title('Scatterplot of Calories by Total Steps')
# Out:
# Text(0.5, 1.0, 'Scatterplot of Calories by Total Steps')

# %%
plt.figure(figsize=(15,8))
ax = sns.boxplot(x='month', y='Calories', data=fit)
#ax = sns.swarmplot(x='month', y='Calories', data=fit, color = 'black')
ax.set_title('Box plot of Calories by month')
# Out:
# Text(0.5, 1.0, 'Box plot of Calories by month')

# %%
plt.figure(figsize = (15,8))
ax= sns.scatterplot(x='Calories', y='TotalDistance', data= fit, color='green')
ax.set_title('Scatterplot of Calories by Total Distance')
# Out:
# Text(0.5, 1.0, 'Scatterplot of Calories by Total Distance')

# %%
plt.figure(figsize=(15,8))
ax = sns.scatterplot(x='Calories', y= 'SedentaryActiveDistance', data=fit, color='green')
ax.set_title('Scatterplot of Calories by Sedentary Distance')
# Out:
# Text(0.5, 1.0, 'Scatterplot of Calories by Sedentary Distance')

# %%
plt.figure(figsize = (15,8))
ax= sns.scatterplot(x='Calories', y='TrackerDistance', data= fit, color='green')
ax.set_title('Scatterplot of Calories by Tracker Distance')
# Out:
# Text(0.5, 1.0, 'Scatterplot of Calories by Tracker Distance')

# %%
plt.figure(figsize = (15,8))
ax= sns.scatterplot(x='Calories', y='LoggedActivitiesDistance', data= fit, color= 'green')
ax.set_title('Scatterplot of Calories by Logged Activities Distance')
# Out:
# Text(0.5, 1.0, 'Scatterplot of Calories by Logged Activities Distance')

# %%
plt.figure(figsize = (15,8))
ax= sns.scatterplot(x='Calories', y='VeryActiveDistance', data= fit, color= 'green')
ax.set_title('Scatterplot of Calories by Very Active Distance')
# Out:
# Text(0.5, 1.0, 'Scatterplot of Calories by Very Active Distance')

# %%
plt.figure(figsize = (15,8))
ax= sns.scatterplot(x='Calories', y='ModeratelyActiveDistance', data= fit, color= 'green')
ax.set_title('Scatterplot of Calories by Moderately Active Distance')
# Out:
# Text(0.5, 1.0, 'Scatterplot of Calories by Moderately Active Distance')

# %%
plt.figure(figsize = (15,8))
ax= sns.scatterplot(x='Calories', y='LightActiveDistance', data= fit, color= 'green')
ax.set_title('Scatterplot of Calories by Light Active Distance')
# Out:
# Text(0.5, 1.0, 'Scatterplot of Calories by Light Active Distance')

# %%
cols=['TotalDistance','LoggedActivitiesDistance','VeryActiveDistance', 'ModeratelyActiveDistance',
          'LightActiveDistance','SedentaryActiveDistance']
diff_act=fit[cols]

plt.figure(figsize=(15,8))
ax= sns.lineplot(data= diff_act)
ax.set_title('Different Activites based on distance')
# Out:
# Text(0.5, 1.0, 'Different Activites based on distance')

# %%
cols=['VeryActiveMinutes','FairlyActiveMinutes','LightlyActiveMinutes','SedentaryMinutes']
diff_act_mins =fit[cols]

plt.figure(figsize=(15,8))
ax= sns.lineplot(data= diff_act_mins)
ax.set_title('Different Activites based on Minutes')
# Out:
# Text(0.5, 1.0, 'Different Activites based on Minutes')

# %%
#A correlation heatmap to show the correlation between columns
cols=['TotalSteps','TotalDistance','TrackerDistance','LoggedActivitiesDistance','VeryActiveDistance',
          'ModeratelyActiveDistance','LightActiveDistance','SedentaryActiveDistance','VeryActiveMinutes',
          'FairlyActiveMinutes','LightlyActiveMinutes','SedentaryMinutes','Calories']

corr_matrix =fit[cols].corr()
plt.figure(figsize=(24,15))
heatmap = sns.heatmap(corr_matrix, vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
#Calculating the daily averages of activity metrics
daily_avg_steps = fit.groupby('day')['TotalSteps'].mean()
daily_avg_calories= fit.groupby('day')['Calories'].mean()

plt.figure(figsize=(12,6))
plt.plot(daily_avg_steps.index, daily_avg_steps.values, label='Average Steps', marker='o')
plt.plot(daily_avg_calories.index, daily_avg_calories.values, label='Average Calories', marker='o')
plt.xlabel('Day')
plt.ylabel('Daily Average')
plt.title('Daily Average Steps and Calories')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Feature Importance
#
# The importance of each feature in predicting the Calories was visualised using a random forest model to understand how each feature in the data contributed to predicting Calories

# %%
from sklearn.ensemble import RandomForestRegressor

cols = ['TotalSteps','TotalDistance','TrackerDistance','LoggedActivitiesDistance','VeryActiveDistance','ModeratelyActiveDistance', 
        'LightActiveDistance','SedentaryActiveDistance','VeryActiveMinutes','FairlyActiveMinutes','LightlyActiveMinutes',
        'SedentaryMinutes']       

# Separating the target variable (Calories) and the features
X = fit[cols] #Features
y =  fit['Calories'] #Target variable

# Create a Random Forest model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model to your data
rf_model.fit(X, y)

# Get feature importances
feature_importances = rf_model.feature_importances_

# Create a DataFrame to store feature names and their importances
feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importances})

# Sort the DataFrame by importance
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.title('Feature Importance')
plt.gca().invert_yaxis()  # Invert the y-axis for better visualization
plt.show()
